# %% [markdown]
# # Antes de empezar:
#
#     Lee el archivo README.md
#     Comenta todo lo que puedas y utiliza los recursos (archivo README.md)
#     ¡Feliz aprendizaje!

# %% [markdown]
# En este ejercicio, generaremos números aleatorios a partir de las disribuciones continuas que aprendimos en la lección. Hay dos formas de generar números aleatorios:
#
# 1. Usando la librería numpy
# 1. Usando la librería Scipy
#
# Utiliza cualquiera de las dos librerías o ambas en este ejercicio.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns
from scipy.stats import uniform

# %% [markdown]
# ## Distribución Uniforme
#
# Para generar números aleatorios uniformes entre dos valores dados usando scipy, podemos usar el siguiente código o el código que hemos
# discutido en clase:

# %%
# your code here

low = 10 # valor mínimo
high = 20 # valor máximo
size = 1000 # cantidad de números aleatorios a generar
random_numbers = uniform.rvs(loc=low, scale=high - low, size=size)
random_numbers
# Out:
# array([10.74957051, 12.62472143, 16.39244752, 17.03326633, 18.49672871,
#        11.01304166, 18.57527196, 13.13638193, 14.60443061, 17.2586372 ,
#        11.74030433, 12.62921315, 12.37112972, 10.80376973, 17.82738793,
#        17.03100848, 12.9010031 , 13.78460665, 13.88565434, 16.05212337,
#        12.79174538, 12.7329118 , 13.42297461, 19.63978416, 12.00132645,
#        15.64836966, 15.35682935, 12.47782085, 15.21460425, 12.31506591,
#        19.1380011 , 14.76481471, 12.9469171 , 15.69948865, 16.74616884,
#        12.8277993 , 13.62000009, 19.34235013, 17.71678214, 10.19025811,
#        18.4685708 , 17.29217616, 13.38244472, 15.34719272, 15.81350877,
#        14.07847277, 13.85205091, 17.91147202, 11.68879666, 15.4273339 ,
#        18.76235565, 14.180528  , 17.77327775, 15.59078991, 10.97766148,
#        19.23298216, 17.6436738 , 14.96179799, 14.51965062, 13.01136183,
#        12.54391604, 16.84298164, 15.01686938, 16.31450787, 19.17044498,
#        14.94005176, 16.36566854, 13.78698811, 17.95005593, 18.89494181,
#        16.05383256, 12.01734516, 11.10390126, 15.15136561, 10.95551693,
#        15.44895308, 11.49955757, 19.03565426, 10.67344669, 16.06578133,
#        12.5119413 , 17.21614965, 10.91777549, 12.90586456, 12.38685383,
#        16.22156419, 15.52164613, 12.82606442, 18.26312635, 18.76891622,
#        11.71912023, 14.52484003, 12.53416277, 18.64674009, 12.09787783,
#        17.49276815, 11.37096926, 18.71155952, 13.4417204 , 12.65954279,
#        11.69793844, 16.56015616, 15.29693132, 16.81334427, 17.44132735,
#        11.30024424, 18.56551829, 12.63995628, 14.73077008, 14.70176668,
#        13.71245685, 17.53407046, 19.77842239, 17.12155741, 19.07215048,
#        15.03185022, 11.13813597, 15.85644452, 10.15375291, 16.7341106 ,
#        11.08948483, 16.40796096, 15.23020025, 17.53692468, 14.64254459,
#        18.65919157, 15.17752458, 15.47221512, 13.02595604, 11.20894207,
#        19.09115196, 13.72674482, 13.1529141 , 13.77703382, 17.4088819 ,
#        15.70680773, 17.78562015, 12.73903223, 13.48937221, 18.31866654,
#        14.27491501, 10.94613113, 14.83292583, 10.78171348, 10.26503159,
#        15.91931487, 16.34777843, 16.75781165, 11.5795809 , 15.24861911,
#        13.23429667, 10.14477691, 14.36065115, 19.74439279, 11.22322005,
#        18.74614246, 12.60944694, 14.58692409, 14.56021721, 19.91255112,
#        15.66859412, 12.69646861, 12.53871321, 14.65867466, 18.15290208,
#        11.74432655, 14.0540538 , 16.44513534, 19.35801083, 16.79320674,
#        12.19668356, 13.70597859, 19.529219  , 19.9177319 , 18.76333529,
#        14.26020407, 13.93282008, 13.2428284 , 13.10672619, 19.62204135,
#        17.70203437, 19.54586542, 17.30924138, 13.58922545, 17.95653177,
#        19.63680026, 14.7589986 , 16.93038785, 12.6656316 , 10.00914206,
#        14.37791434, 12.77100754, 12.01584571, 10.19831003, 18.8953529 ,
#        11.8677915 , 18.02941591, 11.38317069, 14.05970053, 13.13109482,
#        15.82573779, 12.89648596, 17.09662256, 10.05528547, 14.39488816,
#        13.13461812, 14.04470053, 17.66178818, 16.05272043, 19.05487954])

# %% [markdown]
# **Tarea:**
#
# 1. Basándote en el código anterior, escribe una función que genere números aleatorios uniformemente distribuidos. Hay varios requisitos para tu función:
#     * Debe aceptar 3 parámetros:
#         * `bottom` - el límite inferior de los números generados
#         * `ceiling` - el límite superior de los números generados
#         * `count` - cuántos números generar
#     * Debe devolver una matriz de números aleatorios distribuidos uniformemente
#
# 2. Llama a tu función con 2 conjuntos de parámetros a continuación:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 3. Traza las distribuciones uniformes generadas anteriormente utilizando histogramas, donde el eje x es el valor y el eje y es el recuento. Que el número de intervalos del histograma sea 10.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
# your code here

def random_uniform_distribution(bottom, ceiling, count):
    ret = uniform.rvs(loc=bottom, scale=ceiling - bottom, size=count)
    return ret

# %%
# your code here
m1 = random_uniform_distribution(10, 15, 100)
m2 = random_uniform_distribution(10, 60, 1000)

# %%
# your code here


fig, ax = plt.subplots(1,2, sharey=True)

# Histograma m1
sns.histplot(m1, ax=ax[0])
ax[0].set_title('matriz1')
ax[0].set_xlabel('Valor')
ax[0].set_ylabel('Frecuencia')

# Histograma m2
sns.histplot(m2, ax=ax[1])
ax[1].set_title('matriz2')
ax[1].set_xlabel('Valor')

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# Lo que se observa es que las distribuciones son muy parecidas y uniformes. La matriz dos tiene mas valores y en un rango mas amplio, pero lo que es la distribución és la misma

# %% [markdown]
# ## Distribución Normal
#
# 1. De la misma manera en el reto de Distribución Uniforme, escriba una función que genere números aleatorios distribuidos normalmente.
# 1. Genera 1.000 números distribuidos normalmente con media de 10 y desviación típica de 1
# 1. Genera 1.000 números distribuidos normalmente con una media de 10 y una desviación típica de 50
# 2. Representa gráficamente las distribuciones de los datos generados.
#
# Resultado esperado:
#
# ![image.png](attachment:image.png)

# %%
def normal_distribution(media, std, count):
  return norm.rvs(loc=media, scale=std, size=count)

# %%
# your code here
m3 = normal_distribution(10, 1, 1000)
m4 = normal_distribution(10, 50, 1000)

# %%
# your code here
fig, ax = plt.subplots(1, 2, sharey=True)

# Histograma m3
sns.histplot(m3, ax=ax[0])
ax[0].set_title('m3')
ax[0].set_xlabel('Valor')
ax[0].set_ylabel('Frecuencia')

# Histograma m4
sns.histplot(m4, ax=ax[1])
ax[1].set_title('m4')
ax[1].set_xlabel('Valor')

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
#  En esta lo que podemos ver es que  la primera el rango de valores es más pequeño, mientras que la segunda muestra una variación de valores mucho mayor. lo que hace que la distribnución de ambas matrices sean la misma

# %% [markdown]
# ## Distribución Normal de Datos Reales
#
# En este reto vamos a echar un vistazo a los datos reales. Utilizaremos el archivo vehicles.csv para este ejercicio

# %%
# your code here
vehiculo = pd.read_csv('./vehicles.csv')
vehiculo.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# Primero importa vehicles.csv.
# A continuación, traza los histogramas de las siguientes variables:
#
# 1. Barriles de combustible/año

# %%
# your code here
plt.hist(vehiculo["Fuel Barrels/Year"], bins=20)
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Frequency')
plt.title('Distribution of Fuel Barrels/Year')
plt.show()

# %%
# your code here

# %% [markdown]
# 2. Emisiones de CO2 Gramos/Milla

# %%
# your code here
plt.hist(vehiculo["CO2 Emission Grams/Mile"], bins=20)
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Frequency')
plt.title('Distribution of CO2 Emission Grams/Mile')
plt.show()

# %%
# your code here

# %% [markdown]
# 3. MPG combinado

# %%
# your code here
plt.hist(vehiculo["Combined MPG"], bins=20)
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.title('Distribution of Combined MPG')
plt.show()

# %%
# your code here

# %%
# your code here

# %% [markdown]
# ¿Cuál o cuáles de las variables tienen una distribución casi normal? ¿Cómo lo sabes?

# %%
# your code here
from scipy.stats import kstest

variables = ["Combined MPG", "CO2 Emission Grams/Mile", "Fuel Barrels/Year"]

for var in variables:
    stat, p = kstest(vehiculo[var].dropna(), 'norm')
    print(f'K-S Test for {var}: p-value = {p}')
    if p > 0.05:
        print(f'{var} appears to be normally distributed')
    else:
        print(f'{var} does not appear to be normally distributed')
# Out:
# K-S Test for Combined MPG: p-value = 0.0
# Combined MPG does not appear to be normally distributed
# K-S Test for CO2 Emission Grams/Mile: p-value = 0.0
# CO2 Emission Grams/Mile does not appear to be normally distributed
# K-S Test for Fuel Barrels/Year: p-value = 0.0
# Fuel Barrels/Year does not appear to be normally distributed

# %%
# your code here

# %%
# your code here

# %%
# your code here

# %% [markdown]
# Ninguno de ellos está normalmente ditribuido.

# %% [markdown]
# ## Distribución Exponencial

# %% [markdown]
# 1. Utilizando `numpy.random.exponential`, crea una función que devuelva una lista de números distribuidos exponencialmente con la media de 10.
#
# 1. Utiliza la función para generar dos secuencias de números de tamaño 10 y 100.
#
# 1. 2. Traza las distribuciones como histogramas con el número de bins como 100.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ¿En qué se diferencian ambas distribuciones?

# %%
¿En qué se diferencian ambas distribuciones

# %%
# your code here
def numeros_exponencial(media, count):
  return np.random.exponential(media, count)

m5 = numeros_exponencial(10, 10)
m6 = numeros_exponencial(10, 100)

fig, ax = plt.subplots(1, 2)

# Histograma m5
sns.histplot(m5, bins=100, kde=True, ax=ax[0])
ax[0].set_title('m5')
ax[0].set_xlabel('Valor')
ax[0].set_ylabel('Frecuencia')

# Histograma m6
sns.histplot(m6, bins=100, kde=True, ax=ax[1])
ax[1].set_title('m6')
ax[1].set_xlabel('Valor')
ax[1].set_ylabel('Frecuencia')

plt.show()

# %% [markdown]
# La media cambia, por lo que la distribución también cambia.

# %% [markdown]
# ## Distribución Exponencial de datos reales
#
# Supongamos que el tiempo que uno pasa en un banco se distribuye exponencialmente con media de 10 minutos (es decir, λ = 1/10). ¿Cuál es la probabilidad de que un cliente pase menos de quince minutos en el banco?
#
# Escribe un código en python para resolver este problema

# %%
# your code here
λ = 1/10
t = 15

# Formula CDF P(X<15)= 1 − e−^λ.t

# %%
probabilidad = 1 - math.exp(-λ * t)
print(f"{probabilidad*100:.2f}%")
# Out:
# 77.69%

# %% [markdown]
# ¿Cuál es la probabilidad de que el cliente pase más de 15 minutos?

# %%
# your code here

# %%
probabilidad_mas_15 = math.exp(-λ * t)
print(f"{probabilidad_mas_15*100:.2f}%")
# Out:
# 22.31%
